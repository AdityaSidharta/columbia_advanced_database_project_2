# %%
# %cd /home/aditya/git/columbia_advanced_database_project_2/SpanBERT
# Out:
# /home/aditya/git/columbia_advanced_database_project_2/SpanBERT

# %%
import spacy
from spanbert import SpanBERT
from spacy_help_functions import get_entities, create_entity_pairs

# %%
raw_text = "Zuckerberg attended Harvard University, where he launched the Facebook social networking service from his dormitory room on February 4, 2004, with college roommates Eduardo Saverin, Andrew McCollum, Dustin Moskovitz, and Chris Hughes. Bill Gates stepped down as chairman of Microsoft in February 2014 and assumed a new post as technology adviser to support the newly appointed CEO Satya Nadella. "

# %%
# TODO: filter entities of interest based on target relation
entities_of_interest = ["ORGANIZATION", "PERSON", "LOCATION", "CITY", "STATE_OR_PROVINCE", "COUNTRY"]

# %%
# Load spacy model
nlp = spacy.load("en_core_web_lg") 
# Load pre-trained SpanBERT model
spanbert = SpanBERT("./pretrained_spanbert")
# Out:
# 100%|██████████| 213450/213450 [00:00<00:00, 7125880.03B/s]
# Loading pre-trained spanBERT from ./pretrained_spanbert

# %%
# Apply spacy model to raw text (to split to sentences, tokenize, extract entities etc.)
doc = nlp(raw_text)

# %%
sentence = next(doc.sents)

# %%
print("\n\nProcessing entence: {}".format(sentence))
# Out:
# Processing entence: Zuckerberg attended Harvard University, where he launched the Facebook social networking service from his dormitory room on February 4, 2004, with college roommates Eduardo Saverin, Andrew McCollum, Dustin Moskovitz, and Chris Hughes.

# %%
print("Tokenized sentence: {}".format([token.text for token in sentence]))
# Out:
# Tokenized sentence: ['Zuckerberg', 'attended', 'Harvard', 'University', ',', 'where', 'he', 'launched', 'the', 'Facebook', 'social', 'networking', 'service', 'from', 'his', 'dormitory', 'room', 'on', 'February', '4', ',', '2004', ',', 'with', 'college', 'roommates', 'Eduardo', 'Saverin', ',', 'Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.']

# %%
ents = get_entities(sentence, entities_of_interest)
ents
# Out:
# [('Zuckerberg', 'PERSON'),
#  ('Harvard University', 'ORGANIZATION'),
#  ('Facebook', 'ORGANIZATION'),
#  ('February 4, 2004', 'DATE'),
#  ('Eduardo Saverin', 'PERSON'),
#  ('Andrew McCollum', 'PERSON'),
#  ('Dustin Moskovitz', 'PERSON'),
#  ('Chris Hughes', 'PERSON')]

# %%
print("spaCy extracted entities: {}".format(ents))
# Out:
# spaCy extracted entities: [('Zuckerberg', 'PERSON'), ('Harvard University', 'ORGANIZATION'), ('Facebook', 'ORGANIZATION'), ('February 4, 2004', 'DATE'), ('Eduardo Saverin', 'PERSON'), ('Andrew McCollum', 'PERSON'), ('Dustin Moskovitz', 'PERSON'), ('Chris Hughes', 'PERSON')]

# %%
candidate_pairs = []
sentence_entity_pairs = create_entity_pairs(sentence, entities_of_interest)
sentence_entity_pairs
# Out:
# [(['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   ('Zuckerberg', 'PERSON', (0, 0)),
#   ('Harvard University', 'ORGANIZATION', (2, 3))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   ('Zuckerberg', 'PERSON', (0, 0)),
#   ('Facebook', 'ORGANIZATION', (9, 9))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   ('Zuckerberg', 'PERSON', (0, 0)),
#   ('Eduardo Saverin', 'PERSON', (26, 27))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   ('Zuckerberg', 'PERSON', (0, 0)),
#   ('Andrew McCollum', 'PERSON', (29, 30))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   ('Zuckerberg', 'PERSON', (0, 0)),
#   ('Dustin Moskovitz', 'PERSON', (32, 33))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   ('Zuckerberg', 'PERSON', (0, 0)),
#   ('Chris Hughes', 'PERSON', (36, 37))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   ('Harvard University', 'ORGANIZATION', (2, 3)),
#   ('Facebook', 'ORGANIZATION', (9, 9))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   ('Harvard University', 'ORGANIZATION', (2, 3)),
#   ('Eduardo Saverin', 'PERSON', (26, 27))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   ('Harvard University', 'ORGANIZATION', (2, 3)),
#   ('Andrew McCollum', 'PERSON', (29, 30))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   ('Harvard University', 'ORGANIZATION', (2, 3)),
#   ('Dustin Moskovitz', 'PERSON', (32, 33))),
#  (['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   ('Harvard University', 'ORGANIZATION', (2, 3)),
#   ('Chris Hughes', 'PERSON', (36, 37))),
#  (['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   ('Facebook', 'ORGANIZATION', (4, 4)),
#   ('Eduardo Saverin', 'PERSON', (21, 22))),
#  (['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   ('Facebook', 'ORGANIZATION', (4, 4)),
#   ('Andrew McCollum', 'PERSON', (24, 25))),
#  (['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   ('Facebook', 'ORGANIZATION', (4, 4)),
#   ('Dustin Moskovitz', 'PERSON', (27, 28))),
#  (['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   ('Facebook', 'ORGANIZATION', (4, 4)),
#   ('Chris Hughes', 'PERSON', (31, 32))),
#  (['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   ('Eduardo Saverin', 'PERSON', (3, 4)),
#   ('Andrew McCollum', 'PERSON', (6, 7))),
#  (['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   ('Eduardo Saverin', 'PERSON', (3, 4)),
#   ('Dustin Moskovitz', 'PERSON', (9, 10))),
#  (['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   ('Eduardo Saverin', 'PERSON', (3, 4)),
#   ('Chris Hughes', 'PERSON', (13, 14))),
#  (['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   ('Andrew McCollum', 'PERSON', (0, 1)),
#   ('Dustin Moskovitz', 'PERSON', (3, 4))),
#  (['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   ('Andrew McCollum', 'PERSON', (0, 1)),
#   ('Chris Hughes', 'PERSON', (7, 8))),
#  (['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   ('Dustin Moskovitz', 'PERSON', (0, 1)),
#   ('Chris Hughes', 'PERSON', (4, 5)))]

# %%
for ep in sentence_entity_pairs:
    # TODO: keep subject-object pairs of the right type for the target relation (e.g., Person:Organization for the "Work_For" relation)
    candidate_pairs.append({"tokens": ep[0], "subj": ep[1], "obj": ep[2]})  # e1=Subject, e2=Object
    candidate_pairs.append({"tokens": ep[0], "subj": ep[2], "obj": ep[1]})  # e1=Object, e2=Subject

candidate_pairs
# Out:
# [{'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Eduardo Saverin', 'PERSON', (21, 22))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (21, 22)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (24, 25))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (24, 25)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (27, 28))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (27, 28)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (31, 32))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (31, 32)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (6, 7))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (6, 7)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (9, 10))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (9, 10)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (13, 14))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (13, 14)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (7, 8))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (7, 8)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Dustin Moskovitz', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (4, 5))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Chris Hughes', 'PERSON', (4, 5)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (0, 1))},
#  {'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Eduardo Saverin', 'PERSON', (21, 22))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (21, 22)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (24, 25))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (24, 25)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (27, 28))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (27, 28)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (31, 32))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (31, 32)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (6, 7))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (6, 7)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (9, 10))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (9, 10)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (13, 14))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (13, 14)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (7, 8))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (7, 8)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Dustin Moskovitz', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (4, 5))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Chris Hughes', 'PERSON', (4, 5)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (0, 1))}]

# %%
# Classify Relations for all Candidate Entity Pairs using SpanBERT
candidate_pairs = [p for p in candidate_pairs if not p["subj"][1] in ["DATE", "LOCATION"]]  # ignore subject entities with date/location type
print("Candidate entity pairs:")
for p in candidate_pairs:
    print("Subject: {}\tObject: {}".format(p["subj"][0:2], p["obj"][0:2]))
print("Applying SpanBERT for each of the {} candidate pairs. This should take some time...".format(len(candidate_pairs)))
# Out:
# Candidate entity pairs:
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Zuckerberg', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Zuckerberg', 'PERSON')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Harvard University', 'ORGANIZATION')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Harvard University', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Facebook', 'ORGANIZATION')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Facebook', 'ORGANIZATION')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Eduardo Saverin', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Eduardo Saverin', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Andrew McCollum', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Andrew McCollum', 'PERSON')
# Subject: ('Dustin Moskovitz', 'PERSON')	Object: ('Chris Hughes', 'PERSON')
# Subject: ('Chris Hughes', 'PERSON')	Object: ('Dustin Moskovitz', 'PERSON')
# Applying SpanBERT for each of the 84 candidate pairs. This should take some time...

# %%
relation_preds = spanbert.predict(candidate_pairs)  # get predictions: list of (relation, confidence) pairs

# %%
relation_preds
# Out:
# [('no_relation', 0.9982001),
#  ('no_relation', 0.99973303),
#  ('no_relation', 0.965565),
#  ('no_relation', 0.9991116),
#  ('no_relation', 0.99960905),
#  ('no_relation', 0.9988648),
#  ('no_relation', 0.99946415),
#  ('no_relation', 0.9993222),
#  ('no_relation', 0.99741983),
#  ('no_relation', 0.99873334),
#  ('no_relation', 0.9987677),
#  ('no_relation', 0.9981373),
#  ('no_relation', 0.9991116),
#  ('no_relation', 0.99746644),
#  ('no_relation', 0.9997883),
#  ('no_relation', 0.96516734),
#  ('no_relation', 0.999672),
#  ('no_relation', 0.94366294),
#  ('no_relation', 0.9994394),
#  ('per:schools_attended', 0.5659972),
#  ('no_relation', 0.9994556),
#  ('per:schools_attended', 0.5837169),
#  ('no_relation', 0.99886674),
#  ('no_relation', 0.9284509),
#  ('no_relation', 0.99821824),
#  ('no_relation', 0.9071047),
#  ('no_relation', 0.9977081),
#  ('per:employee_of', 0.8343476),
#  ('no_relation', 0.99783653),
#  ('per:employee_of', 0.63332117),
#  ('no_relation', 0.97285414),
#  ('no_relation', 0.99438155),
#  ('no_relation', 0.9804151),
#  ('no_relation', 0.9864908),
#  ('no_relation', 0.99284077),
#  ('no_relation', 0.9955287),
#  ('no_relation', 0.9918357),
#  ('no_relation', 0.9955059),
#  ('no_relation', 0.9975654),
#  ('no_relation', 0.99954045),
#  ('no_relation', 0.99692345),
#  ('no_relation', 0.9983696),
#  ('no_relation', 0.9982001),
#  ('no_relation', 0.99973303),
#  ('no_relation', 0.965565),
#  ('no_relation', 0.9991116),
#  ('no_relation', 0.99960905),
#  ('no_relation', 0.9988648),
#  ('no_relation', 0.99946415),
#  ('no_relation', 0.9993222),
#  ('no_relation', 0.99741983),
#  ('no_relation', 0.99873334),
#  ('no_relation', 0.9987677),
#  ('no_relation', 0.9981373),
#  ('no_relation', 0.9991116),
#  ('no_relation', 0.99746644),
#  ('no_relation', 0.9997883),
#  ('no_relation', 0.96516734),
#  ('no_relation', 0.999672),
#  ('no_relation', 0.94366294),
#  ('no_relation', 0.9994394),
#  ('per:schools_attended', 0.5659972),
#  ('no_relation', 0.9994556),
#  ('per:schools_attended', 0.5837169),
#  ('no_relation', 0.99886674),
#  ('no_relation', 0.9284509),
#  ('no_relation', 0.99821824),
#  ('no_relation', 0.9071047),
#  ('no_relation', 0.9977081),
#  ('per:employee_of', 0.8343476),
#  ('no_relation', 0.99783653),
#  ('per:employee_of', 0.63332117),
#  ('no_relation', 0.97285414),
#  ('no_relation', 0.99438155),
#  ('no_relation', 0.9804151),
#  ('no_relation', 0.9864908),
#  ('no_relation', 0.99284077),
#  ('no_relation', 0.9955287),
#  ('no_relation', 0.9918357),
#  ('no_relation', 0.9955059),
#  ('no_relation', 0.9975654),
#  ('no_relation', 0.99954045),
#  ('no_relation', 0.99692345),
#  ('no_relation', 0.9983696)]

# %%
candidate_pairs
# Out:
# [{'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Eduardo Saverin', 'PERSON', (21, 22))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (21, 22)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (24, 25))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (24, 25)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (27, 28))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (27, 28)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (31, 32))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (31, 32)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (6, 7))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (6, 7)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (9, 10))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (9, 10)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (13, 14))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (13, 14)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (7, 8))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (7, 8)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Dustin Moskovitz', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (4, 5))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Chris Hughes', 'PERSON', (4, 5)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (0, 1))},
#  {'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg', 'attended', 'Harvard', 'University', ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Zuckerberg', 'PERSON', (0, 0)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Zuckerberg', 'PERSON', (0, 0))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Facebook', 'ORGANIZATION', (9, 9))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (9, 9)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Eduardo Saverin', 'PERSON', (26, 27))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (26, 27)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Andrew McCollum', 'PERSON', (29, 30))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (29, 30)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (32, 33))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (32, 33)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Harvard University', 'ORGANIZATION', (2, 3)),
#   'obj': ('Chris Hughes', 'PERSON', (36, 37))},
#  {'tokens': ['Zuckerberg',
#    'attended',
#    'Harvard',
#    'University',
#    ',',
#    'where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (36, 37)),
#   'obj': ('Harvard University', 'ORGANIZATION', (2, 3))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Eduardo Saverin', 'PERSON', (21, 22))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (21, 22)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (24, 25))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (24, 25)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (27, 28))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (27, 28)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Facebook', 'ORGANIZATION', (4, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (31, 32))},
#  {'tokens': ['where',
#    'he',
#    'launched',
#    'the',
#    'Facebook',
#    'social',
#    'networking',
#    'service',
#    'from',
#    'his',
#    'dormitory',
#    'room',
#    'on',
#    'February',
#    '4',
#    ',',
#    '2004',
#    ',',
#    'with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (31, 32)),
#   'obj': ('Facebook', 'ORGANIZATION', (4, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (6, 7))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ','],
#   'subj': ('Andrew McCollum', 'PERSON', (6, 7)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (9, 10))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (9, 10)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Eduardo Saverin', 'PERSON', (3, 4)),
#   'obj': ('Chris Hughes', 'PERSON', (13, 14))},
#  {'tokens': ['with',
#    'college',
#    'roommates',
#    'Eduardo',
#    'Saverin',
#    ',',
#    'Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (13, 14)),
#   'obj': ('Eduardo Saverin', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (3, 4))},
#  {'tokens': ['Andrew', 'McCollum', ',', 'Dustin', 'Moskovitz', ','],
#   'subj': ('Dustin Moskovitz', 'PERSON', (3, 4)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Andrew McCollum', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (7, 8))},
#  {'tokens': ['Andrew',
#    'McCollum',
#    ',',
#    'Dustin',
#    'Moskovitz',
#    ',',
#    'and',
#    'Chris',
#    'Hughes',
#    '.'],
#   'subj': ('Chris Hughes', 'PERSON', (7, 8)),
#   'obj': ('Andrew McCollum', 'PERSON', (0, 1))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Dustin Moskovitz', 'PERSON', (0, 1)),
#   'obj': ('Chris Hughes', 'PERSON', (4, 5))},
#  {'tokens': ['Dustin', 'Moskovitz', ',', 'and', 'Chris', 'Hughes', '.'],
#   'subj': ('Chris Hughes', 'PERSON', (4, 5)),
#   'obj': ('Dustin Moskovitz', 'PERSON', (0, 1))}]

# %%
print("\nExtracted relations:")
for ex, pred in list(zip(candidate_pairs, relation_preds)):
    print("\tSubject: {}\tObject: {}\tRelation: {}\tConfidence: {:.2f}".format(ex["subj"][0], ex["obj"][0], pred[0], pred[1]))
# Out:
# Extracted relations:
# 	Subject: Zuckerberg	Object: Harvard University	Relation: no_relation	Confidence: 1.00
# 	Subject: Harvard University	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Facebook	Relation: no_relation	Confidence: 0.97
# 	Subject: Facebook	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Eduardo Saverin	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Harvard University	Object: Facebook	Relation: no_relation	Confidence: 1.00
# 	Subject: Facebook	Object: Harvard University	Relation: no_relation	Confidence: 1.00
# 	Subject: Harvard University	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Eduardo Saverin	Object: Harvard University	Relation: no_relation	Confidence: 0.97
# 	Subject: Harvard University	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Harvard University	Relation: no_relation	Confidence: 0.94
# 	Subject: Harvard University	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Harvard University	Relation: per:schools_attended	Confidence: 0.57
# 	Subject: Harvard University	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Harvard University	Relation: per:schools_attended	Confidence: 0.58
# 	Subject: Facebook	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Eduardo Saverin	Object: Facebook	Relation: no_relation	Confidence: 0.93
# 	Subject: Facebook	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Facebook	Relation: no_relation	Confidence: 0.91
# 	Subject: Facebook	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Facebook	Relation: per:employee_of	Confidence: 0.83
# 	Subject: Facebook	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Facebook	Relation: per:employee_of	Confidence: 0.63
# 	Subject: Eduardo Saverin	Object: Andrew McCollum	Relation: no_relation	Confidence: 0.97
# 	Subject: Andrew McCollum	Object: Eduardo Saverin	Relation: no_relation	Confidence: 0.99
# 	Subject: Eduardo Saverin	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 0.98
# 	Subject: Dustin Moskovitz	Object: Eduardo Saverin	Relation: no_relation	Confidence: 0.99
# 	Subject: Eduardo Saverin	Object: Chris Hughes	Relation: no_relation	Confidence: 0.99
# 	Subject: Chris Hughes	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 0.99
# 	Subject: Dustin Moskovitz	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Harvard University	Relation: no_relation	Confidence: 1.00
# 	Subject: Harvard University	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Facebook	Relation: no_relation	Confidence: 0.97
# 	Subject: Facebook	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Eduardo Saverin	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Zuckerberg	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Zuckerberg	Relation: no_relation	Confidence: 1.00
# 	Subject: Harvard University	Object: Facebook	Relation: no_relation	Confidence: 1.00
# 	Subject: Facebook	Object: Harvard University	Relation: no_relation	Confidence: 1.00
# 	Subject: Harvard University	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Eduardo Saverin	Object: Harvard University	Relation: no_relation	Confidence: 0.97
# 	Subject: Harvard University	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Harvard University	Relation: no_relation	Confidence: 0.94
# 	Subject: Harvard University	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Harvard University	Relation: per:schools_attended	Confidence: 0.57
# 	Subject: Harvard University	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Harvard University	Relation: per:schools_attended	Confidence: 0.58
# 	Subject: Facebook	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Eduardo Saverin	Object: Facebook	Relation: no_relation	Confidence: 0.93
# 	Subject: Facebook	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Facebook	Relation: no_relation	Confidence: 0.91
# 	Subject: Facebook	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Facebook	Relation: per:employee_of	Confidence: 0.83
# 	Subject: Facebook	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Facebook	Relation: per:employee_of	Confidence: 0.63
# 	Subject: Eduardo Saverin	Object: Andrew McCollum	Relation: no_relation	Confidence: 0.97
# 	Subject: Andrew McCollum	Object: Eduardo Saverin	Relation: no_relation	Confidence: 0.99
# 	Subject: Eduardo Saverin	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 0.98
# 	Subject: Dustin Moskovitz	Object: Eduardo Saverin	Relation: no_relation	Confidence: 0.99
# 	Subject: Eduardo Saverin	Object: Chris Hughes	Relation: no_relation	Confidence: 0.99
# 	Subject: Chris Hughes	Object: Eduardo Saverin	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 0.99
# 	Subject: Dustin Moskovitz	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Andrew McCollum	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Andrew McCollum	Relation: no_relation	Confidence: 1.00
# 	Subject: Dustin Moskovitz	Object: Chris Hughes	Relation: no_relation	Confidence: 1.00
# 	Subject: Chris Hughes	Object: Dustin Moskovitz	Relation: no_relation	Confidence: 1.00

# %%
for sentence in doc.sents:  
    print("\n\nProcessing entence: {}".format(sentence))
    print("Tokenized sentence: {}".format([token.text for token in sentence]))
    ents = get_entities(sentence, entities_of_interest)
    print("spaCy extracted entities: {}".format(ents))
    # create entity pairs
    candidate_pairs = []
    sentence_entity_pairs = create_entity_pairs(sentence, entities_of_interest)
    for ep in sentence_entity_pairs:
        # TODO: keep subject-object pairs of the right type for the target relation (e.g., Person:Organization for the "Work_For" relation)
        candidate_pairs.append({"tokens": ep[0], "subj": ep[1], "obj": ep[2]})  # e1=Subject, e2=Object
        candidate_pairs.append({"tokens": ep[0], "subj": ep[2], "obj": ep[1]})  # e1=Object, e2=Subject
    

    # Classify Relations for all Candidate Entity Pairs using SpanBERT
    candidate_pairs = [p for p in candidate_pairs if not p["subj"][1] in ["DATE", "LOCATION"]]  # ignore subject entities with date/location type
    print("Candidate entity pairs:")
    for p in candidate_pairs:
        print("Subject: {}\tObject: {}".format(p["subj"][0:2], p["obj"][0:2]))
    print("Applying SpanBERT for each of the {} candidate pairs. This should take some time...".format(len(candidate_pairs)))

    if len(candidate_pairs) == 0:
        continue
    
    relation_preds = spanbert.predict(candidate_pairs)  # get predictions: list of (relation, confidence) pairs

    # Print Extracted Relations
    print("\nExtracted relations:")
    for ex, pred in list(zip(candidate_pairs, relation_preds)):
        print("\tSubject: {}\tObject: {}\tRelation: {}\tConfidence: {:.2f}".format(ex["subj"][0], ex["obj"][0], pred[0], pred[1]))

        # TODO: focus on target relations
        # '1':"per:schools_attended"
        # '2':"per:employee_of"
        # '3':"per:cities_of_residence"
        # '4':"org:top_members/employees"
